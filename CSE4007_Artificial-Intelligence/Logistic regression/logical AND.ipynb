# %% [markdown]
# # Logistic regression : logical AND

# %%
import random
from math import exp, log

# %% [markdown]
# ## Data preparation

# %%
X = [(0, 0), (1, 0), (0, 1), (1, 1)]
Y = [0, 0, 0, 1]

# %% [markdown]
# ## Model

# %%
class logistic_regression_model():
    def __init__(self):
        self.w = [random.random(), random.random()]
        self.b = random.random()
        
    def sigmoid(self, z):
        return 1/(1+exp(-z))
    
    def predict(self, x):
        z = self.w[0] * x[0] + self.w[1] * x[1] + self.b
        a = self.sigmoid(z)
        return a

# %%
model = logistic_regression_model()

# %% [markdown]
# ## Training

# %%
def train(X, Y, model, lr = 0.1):
    dw0 = 0.0
    dw1 = 0.0
    db = 0.0
    m = len(X)
    cost = 0.0
    for x, y in zip(X, Y):
        a = model.predict(x)
        if y == 1:
            cost -= log(a)
        else:
            cost -= log(1-a)
            
        dw0 += (a-y)*x[0]
        dw1 += (a-y)*x[1]
        db += (a-y)
        
    cost /= m
    model.w[0] -= lr * dw0/m
    model.w[1] -= lr * dw1/m
    model.b -= lr * db/m
    
    return cost

# %%
for epoch in range(10000):
    cost = train(X, Y, model, 0.1)
    if epoch %100 == 0:
        print(epoch, cost)
# Out:
# 0 1.1392813664533599
# 100 0.46613940166142676
# 200 0.36518692325955227
# 300 0.30305595138739505
# 400 0.2603975565804021
# 500 0.22890902947803943
# 600 0.2044954799055393
# 700 0.1848997136148609
# 800 0.16876415623079
# 900 0.15521531530374155
# 1000 0.14366083727609202
# 1100 0.13368200309972325
# 1200 0.12497281945766159
# 1300 0.11730352820278533
# 1400 0.11049770080534926
# 1500 0.10441728456644486
# 1600 0.09895250964719522
# 1700 0.0940148803310244
# 1800 0.08953218736586188
# 1900 0.08544488235257656
# 2000 0.08170339282101269
# 2100 0.07826610114421688
# 2200 0.07509780093954908
# 2300 0.07216850279340643
# 2400 0.06945249945378351
# 2500 0.06692762639533627
# 2600 0.06457467131955856
# 2700 0.06237689846831129
# 2800 0.06031966235490893
# 2900 0.05839009178896469
# 3000 0.05657682963893515
# 3100 0.054869817143207905
# 3200 0.05326011409002063
# 3300 0.051739748076129195
# 3400 0.050301587490599
# 3500 0.048939233971747896
# 3600 0.04764693093710644
# 3700 0.046419485450012635
# 3800 0.04525220120737945
# 3900 0.044140820844765866
# 4000 0.04308147608215805
# 4100 0.042070644495662834
# 4200 0.04110511191091461
# 4300 0.040181939584323
# 4400 0.03929843547673793
# 4500 0.03845212903719429
# 4600 0.037640749007190305
# 4700 0.03686220383241768
# 4800 0.03611456433215155
# 4900 0.03539604832907681
# 5000 0.034705006986186705
# 5100 0.034039912634085706
# 5200 0.03339934790286317
# 5300 0.032781995998685
# 5400 0.03218663198721976
# 5500 0.03161211496464619
# 5600 0.031057381012835734
# 5700 0.03052143684882658
# 5800 0.03000335409026603
# 5900 0.029502264068420367
# 6000 0.029017353128878307
# 6100 0.028547858367428437
# 6200 0.028093063754942554
# 6300 0.027652296610601923
# 6400 0.027224924387577096
# 6500 0.02681035173943063
# 6600 0.026408017839131583
# 6700 0.02601739392573791
# 6800 0.0256379810565709
# 6900 0.025269308045136156
# 7000 0.024910929567179448
# 7100 0.024562424419144437
# 7200 0.02422339391495628
# 7300 0.02389346040851731
# 7400 0.02357226593059733
# 7500 0.023259470929946076
# 7600 0.02295475310947588
# 7700 0.0226578063492653
# 7800 0.022368339708944127
# 7900 0.02208607650273367
# 8000 0.021810753441062508
# 8100 0.021542119833248698
# 8200 0.021279936846254094
# 8300 0.021023976814976593
# 8400 0.020774022599958572
# 8500 0.02052986698876403
# 8600 0.020291312137606852
# 8700 0.020058169050118257
# 8800 0.019830257090410187
# 8900 0.01960740352783798
# 9000 0.0193894431110869
# 9100 0.019176217669408958
# 9200 0.018967575739016793
# 9300 0.018763372212807952
# 9400 0.018563468011741108
# 9500 0.018367729776323723
# 9600 0.018176029576792985
# 9700 0.01798824464068555
# 9800 0.017804257096593924
# 9900 0.017623953733001428

# %% [markdown]
# ## Testing

# %%
print(model.predict((0, 0)))
print(model.predict((0, 1)))
print(model.predict((1, 0)))
print(model.predict((1, 1)))
# Out:
# 1.2517628370644411e-05
# 0.020275396968218767
# 0.020275392958323965
# 0.9716021575692698
